# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
# !wget https://readcenter.org/wp-content/uploads/2020/02/4fa9d18c567a8c5a05997a9773685361-1024x768.jpg -O p.jpg
# Out:
# --2023-09-22 14:46:18--  https://readcenter.org/wp-content/uploads/2020/02/4fa9d18c567a8c5a05997a9773685361-1024x768.jpg
# Resolving readcenter.org (readcenter.org)... 69.168.84.74
# Connecting to readcenter.org (readcenter.org)|69.168.84.74|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 98328 (96K) [image/jpeg]
# Saving to: ‘p.jpg’
#
# p.jpg               100%[===================>]  96.02K  --.-KB/s    in 0.1s
#
# 2023-09-22 14:46:18 (862 KB/s) - ‘p.jpg’ saved [98328/98328]

# %%
img=cv2.imread("/content/p.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Out:
# --2023-09-22 14:47:51--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘haarcascade_frontalface_default.xml’
#
# haarcascade_frontal 100%[===================>] 908.33K  --.-KB/s    in 0.04s
#
# 2023-09-22 14:47:51 (22.2 MB/s) - ‘haarcascade_frontalface_default.xml’ saved [930127/930127]

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye.xml
# Out:
# --2023-09-22 14:48:11--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 341406 (333K) [text/plain]
# Saving to: ‘haarcascade_eye.xml’
#
# haarcascade_eye.xml 100%[===================>] 333.40K  --.-KB/s    in 0.04s
#
# 2023-09-22 14:48:12 (8.95 MB/s) - ‘haarcascade_eye.xml’ saved [341406/341406]

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_smile.xml
# Out:
# --2023-09-22 14:48:36--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_smile.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 188506 (184K) [text/plain]
# Saving to: ‘haarcascade_smile.xml’
#
# haarcascade_smile.x 100%[===================>] 184.09K  --.-KB/s    in 0.03s
#
# 2023-09-22 14:48:37 (6.96 MB/s) - ‘haarcascade_smile.xml’ saved [188506/188506]

# %%
img=cv2.imread("/content/p.jpg")
face_model=cv2.CascadeClassifier("/content/haarcascade_frontalface_default.xml")
faces=face_model.detectMultiScale(img,1.2,20)
eye_model=cv2.CascadeClassifier("/content/haarcascade_eye.xml")
eyes=eye_model.detectMultiScale(img,1.2,20)
smile_model=cv2.CascadeClassifier("/content/haarcascade_smile.xml")
smiles=smile_model.detectMultiScale(img,1.2,130)
for (x,y,w,h) in faces:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),4)
for (x,y,w,h) in eyes:
  cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
for (x,y,w,h) in smiles:
  cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,255),3)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>
